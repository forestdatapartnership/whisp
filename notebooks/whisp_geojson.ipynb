# %% [markdown]
# ### Whisp a feature collection

# %% [markdown]
# Import packages
# - NB to avoid complications from altering main python environment run using a virtual environment (https://docs.python.org/3/tutorial/venv.html)

# %%
import ee

import pandas as pd

from pathlib import Path

import whisp

ee.Authenticate()
ee.Initialize()

# %% [markdown]
# Get a feature collection

# %%
GEOJSON_EXAMPLE_FILEPATH = (
    Path.cwd().parents[0]/ "test" / "fixtures" / "geojson_example.geojson"
)
print(GEOJSON_EXAMPLE_FILEPATH)
# Out:
# c:\Users\Arnell\Documents\GitHub\whisp_sustaain\test\fixtures\geojson_example.geojson

# %% [markdown]
# Whisp it

# %%
df_formatted_stats = whisp.whisp_formatted_stats_geojson_to_df(GEOJSON_EXAMPLE_FILEPATH)
# Out:
# Received geojson_filepath: c:\Users\Arnell\Documents\GitHub\whisp_sustaain\test\fixtures\geojson_example.geojson
# Reading GeoJSON file from: c:\Users\Arnell\Documents\GitHub\whisp_sustaain\test\fixtures\geojson_example.geojson
# ['Plot_area_ha', 'Cocoa_bnetd', 'Oil_palm_Descals', 'ESA_fire_before_2020', 'ESA_fire_2001', 'ESA_fire_2002', 'ESA_fire_2003', 'ESA_fire_2004', 'ESA_fire_2005', 'ESA_fire_2006', 'ESA_fire_2007', 'ESA_fire_2008', 'ESA_fire_2009', 'ESA_fire_2010', 'ESA_fire_2011', 'ESA_fire_2012', 'ESA_fire_2013', 'ESA_fire_2014', 'ESA_fire_2015', 'ESA_fire_2016', 'ESA_fire_2017', 'ESA_fire_2018', 'ESA_fire_2019', 'ESA_fire_2020', 'ESA_TC_2020', 'Cocoa_ETH', 'Cocoa_FDaP', 'Forest_FDaP', 'Oil_palm_FDaP', 'Rubber_FDaP', 'GFC_TC_2020', 'GFC_loss_after_2020', 'GFC_loss_before_2020', 'GFC_loss_year_2001', 'GFC_loss_year_2002', 'GFC_loss_year_2003', 'GFC_loss_year_2004', 'GFC_loss_year_2005', 'GFC_loss_year_2006', 'GFC_loss_year_2007', 'GFC_loss_year_2008', 'GFC_loss_year_2009', 'GFC_loss_year_2010', 'GFC_loss_year_2011', 'GFC_loss_year_2012', 'GFC_loss_year_2013', 'GFC_loss_year_2014', 'GFC_loss_year_2015', 'GFC_loss_year_2016', 'GFC_loss_year_2017', 'GFC_loss_year_2018', 'GFC_loss_year_2019', 'GFC_loss_year_2020', 'GFC_loss_year_2021', 'GFC_loss_year_2022', 'GFC_loss_year_2023', 'GLAD_Primary', 'JAXA_FNF_2020', 'EUFO_2020', 'TMF_plant', 'TMF_undist', 'MODIS_fire_after_2020', 'MODIS_fire_before_2020', 'MODIS_fire_2000', 'MODIS_fire_2001', 'MODIS_fire_2002', 'MODIS_fire_2003', 'MODIS_fire_2004', 'MODIS_fire_2005', 'MODIS_fire_2006', 'MODIS_fire_2007', 'MODIS_fire_2008', 'MODIS_fire_2009', 'MODIS_fire_2010', 'MODIS_fire_2011', 'MODIS_fire_2012', 'MODIS_fire_2013', 'MODIS_fire_2014', 'MODIS_fire_2015', 'MODIS_fire
_deg_2013': 0, 'TMF_deg_2014': 0, 'TMF_deg_2015': 0, 'TMF_deg_2016': 0, 'TMF_deg_2017': 0, 'TMF_deg_2018': 0, 'TMF_deg_2019': 0, 'TMF_deg_2020': 0, 'TMF_deg_2021': 0, 'TMF_deg_2022': 0, 'TMF_deg_2023': 0, 'TMF_deg_after_2020': 0, 'TMF_deg_before_2020': 0.637, 'TMF_plant': 0, 'TMF_undist': 0, 'Unit': 'ha', 'water_flag': '-'}}
# File C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\parameters\lookup_gee_datasets.csv changed, updating schema...
# File C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\parameters\lookup_context_and_metadata.csv changed, updating schema...
# Creating or updating schema based on changed files...
# Schema DataFrame columns: Index(['name', 'order', 'theme', 'use_for_risk', 'exclude_from_output',
#        'col_type', 'is_nullable', 'is_required', 'corresponding_variable',
#        'exclude_from_input'],
#       dtype='object')
# Processing column: Plot_id, Type: string, Nullable: True, Required: False
# Processing column: Geo_id, Type: string, Nullable: True, Required: False
# Processing column: Plot_area_ha, Type: float32, Nullable: True, Required: True
# Processing column: Geometry_type, Type: string, Nullable: True, Required: True
# Processing column: Country, Type: string, Nullable: True, Required: True
# Processing column: Admin_Level_1, Type: string, Nullable: True, Required: True
# Processing column: Centroid_lon, Type: float64, Nullable: True, Required: True
# Processing column: Centroid_lat, Type: float64, Nullable: True, Required: True
# Processing column: Unit, Type: string, Nullable: True, Required: True
# Processing column: water_flag, Type: string, Nullable: True, Required: True
# Processing column: EUFO_2020, Type: float32, Nullable: True, Required: False
# Processing column: GLAD_Primary, Type: float32, Nullable: True, Required: False
# Processing column: TMF_undist, Type: float32, Nullable: True, Required: False
# Processing column: JAXA_FNF_2020, Type: float32, Nullable: True, Required: False
# Processing column: GFC_TC_2020, Type: float32, Nullable: True, Required: False
# Processing column: Forest_FDaP, Type: float32, Nullable: True, Required: False
# Processing column: ESA_TC_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_plant, Type: float32, Nullable: True, Required: False
# Processing column: Oil_palm_Descals, Type: float32, Nullable: True, Required: False
# Processing column: Oil_palm_FDaP, Type: float32, Nullable: True, Required: False
# Processing column: Cocoa_FDaP, Type: float32, Nullable: True, Required: False
# Processing column: Cocoa_ETH, Type: float32, Nullable: True, Required: False
# Processing column: Cocoa_bnetd, Type: float32, Nullable: True, Required: False
# Processing column: Rubber_FDaP, Type: float32, Nullable: True, Required: False
# Processing column: Rubber_RBGE, Type: float32, Nullable: True, Required: False
# Processing column: WDPA, Type: bool, Nullable: True, Required: False
# Processing column: TMF_def_2000, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2001, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2002, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2003, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2004, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2005, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2006, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2007, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2008, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2009, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2010, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2011, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2012, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2013, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2014, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2015, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2016, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2017, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2018, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2019, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2021, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2022, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_2023, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2000, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2001, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2002, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2003, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2004, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2005, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2006, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2007, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2008, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2009, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2010, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2011, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2012, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2013, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2014, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2015, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2016, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2017, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2018, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2019, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2021, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2022, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_2023, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2001, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2002, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2003, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2004, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2005, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2006, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2007, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2008, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2009, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2010, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2011, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2012, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2013, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2014, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2015, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2016, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2017, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2018, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2019, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2020, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2021, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2022, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_year_2023, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2019, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2020, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2021, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2022, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2023, Type: float32, Nullable: True, Required: False
# Processing column: RADD_year_2024, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2001, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2002, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2003, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2004, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2005, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2006, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2007, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2008, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2009, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2010, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2011, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2012, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2013, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2014, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2015, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2016, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2017, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2018, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2019, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_2020, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2000, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2001, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2002, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2003, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2004, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2005, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2006, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2007, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2008, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2009, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2010, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2011, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2012, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2013, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2014, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2015, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2016, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2017, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2018, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2019, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2020, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2021, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2022, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2023, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_2024, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: ESA_fire_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: RADD_before_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_deg_after_2020, Type: float32, Nullable: True, Required: False
# Processing column: TMF_def_after_2020, Type: float32, Nullable: True, Required: False
# Processing column: GFC_loss_after_2020, Type: float32, Nullable: True, Required: False
# Processing column: MODIS_fire_after_2020, Type: float32, Nullable: True, Required: False
# Processing column: RADD_after_2020, Type: float32, Nullable: True, Required: False
# [reformat.py | log_missing_columns() | l.312] INFO: All columns from 'df_stats' found in the schema.
# [reformat.py | log_missing_columns() | l.316] WARNING: The following columns in the schema did not match any columns in 'df_stats': Plot_id, Geo_id, WDPA

# %% [markdown]
# Display table

# %%
df_formatted_stats #view output dataframe
# Out:
#     Plot_id  Geo_id  Plot_area_ha Geometry_type Country  \
# 0       NaN     NaN      1.939000       Polygon     GHA
# 1       NaN     NaN      4.152000       Polygon     GHA
# 2       NaN     NaN     16.600000       Polygon     GHA
# 3       NaN     NaN     31.212999       Polygon     IDN
# 4       NaN     NaN      1.964000       Polygon     IDN
# 5       NaN     NaN     12.725000       Polygon     IDN
# 6       NaN     NaN     20.882000       Polygon     IDN
# 7       NaN     NaN      8.279000       Polygon     CIV
# 8       NaN     NaN      1.981000       Polygon     CIV
# 9       NaN     NaN      3.797000       Polygon     CIV
# 10      NaN     NaN      3.615000       Polygon     CIV
# 11      NaN     NaN      0.236000       Polygon     NIC
# 12      NaN     NaN      2.255000       Polygon     NIC
# 13      NaN     NaN      0.799000       Polygon     NIC
# 14      NaN     NaN      0.269000       Polygon     NIC
# 15      NaN     NaN      1.019000       Polygon     CMR
# 16      NaN     NaN      1.006000       Polygon     CMR
# 17      NaN     NaN      4.242000       Polygon     CMR
# 18      NaN     NaN      0.435000       Polygon     CMR
# 19      NaN     NaN      8.086000       Polygon     VNM
# 20      NaN     NaN      7.574000       Polygon     VNM
# 21      NaN     NaN      7.363000       Polygon     VNM
# 22      NaN     NaN      6.879000       Polygon     VNM
# 23      NaN     NaN      6.204000       Polygon     VNM
# 24      NaN     NaN      6.192000       Polygon     VNM
# 25      NaN     NaN      5.648000       Polygon     VNM
# 26      NaN     NaN      5.578000       Polygon     VNM
# 27      NaN     NaN      5.296000       Polygon     FIN
# 28      NaN     NaN      3.725000       Polygon     SWE
# 29      NaN     NaN      3.014000       Polygon     FRA
# 30      NaN     NaN      2.649000       Polygon     FRA
#
#                   Admin_Level_1  Centroid_lon  Centroid_lat Unit water_flag  \
# 0                Ashanti Region     -1.611942      6.159540   ha          -
# 1                Ashanti Region     -1.644732      6.104735   ha          -
# 2                Western Region     -2.157144      5.981149   ha          -
# 3                 South Sumatra    103.956096     -3.054668   ha          -
# 4                 South Sumatra    103.970371     -3.068831   ha          -
# 5                 South Sumatra    103.975182     -3.082922   ha          -
# 6                 South Sumatra    103.977512     -3.083808   ha          -
# 7                       Lagunes     -4.101646      5.711935   ha          -
# 8                       Lagunes     -4.086848      5.673811   ha          -
# 9   District Autonome D'Abidjan     -4.119589      5.572136   ha          -
# 10                    Montagnes     -7.507022      6.071468   ha          -
# 11      Jinotega (Departamento)    -85.929673     13.298333   ha          -
# 12      Jinotega (Departamento)    -85.626848     13.539724   ha          -
# 13      Jinotega (Departamento)    -85.944465     13.166413   ha          -
# 14      Jinotega (Departamento)    -85.854650     13.290698   ha          -
# 15                       Centre     12.596546      4.232426   ha          -
# 16                       Centre     12.640107      4.199724   ha          -
# 17                       Centre     12.328070      4.258412   ha          -
# 18                       Centre     12.592323      4.229365   ha          -
# 19                      Gia Lai    108.063222     13.787460   ha          -
# 20                      ??k L?k    108.102666     12.939684   ha          -
# 21                      Gia Lai    108.048842     13.661566   ha          -
# 22                      Gia Lai    108.041977     13.736411   ha          -
# 23                     ??k Nông    107.588837     12.277016   ha          -
# 24                     ??k Nông    107.648926     12.324585   ha          -
# 25                      Gia Lai    108.120358     13.721797   ha          -
# 26                      ??k L?k    108.102197     12.913104   ha          -
# 27             Northern Savonia     27.032601     63.055631   ha          -
# 28               Gävleborgs län     15.882112     61.603567   ha          -
# 29           Nouvelle-Aquitaine     -0.556281     44.460203   ha          -
# 30           Nouvelle-Aquitaine     -0.521005     44.357837   ha          -
#
#     ...  TMF_def_before_2020  GFC_loss_before_2020  ESA_fire_before_2020  \
# 0   ...                0.511              1.552000              0.000000
# 1   ...                2.880              2.724000              0.000000
# 2   ...                0.000              0.000000              0.000000
# 3   ...               22.218             31.021999             31.212999
# 4   ...                1.954              1.950000              0.000000
# 5   ...                1.453              1.899000              0.000000
# 6   ...                4.546              9.043000              0.000000
# 7   ...                2.535              3.194000              0.000000
# 8   ...                0.924              0.435000              0.000000
# 9   ...                0.096              1.161000              0.000000
# 10  ...                0.959              1.956000              0.000000
# 11  ...                0.000              0.000000              0.000000
# 12  ...                0.000              0.000000              0.000000
# 13  ...                0.000              0.000000              0.000000
# 14  ...                0.000              0.000000              0.000000
# 15  ...                0.000              0.000000              0.000000
# 16  ...                0.590              0.485000              0.000000
# 17  ...                0.000              0.000000              0.000000
# 18  ...                0.002              0.164000              0.000000
# 14            0.000
# 15            0.000
# 16            0.006
# 17            0.000
# 18            0.000
# 19            0.000
# 20            0.000
# 21            0.000
# 22            0.000
# 23            0.000
# 24            0.000
# 25            0.000
# 26            0.000
# 27            0.000
# 28            0.000
# 29            0.000
# 30            0.000
#
# [31 rows x 159 columns]

# %% [markdown]
# Export csv

# %%
# Define output directory
out_directory = Path.cwd().parents[0] / "test" / "output" # directory untracked by git

# Define output file path
output_stats_file = out_directory / "whisp_output_table.csv" # edit as required

# Save statistics to CSV
df_formatted_stats.to_csv(path_or_buf=output_stats_file,index=False)

print(f"Formatted stats saved to: {output_stats_file}")
# Out:
# Formatted stats saved to: c:\Users\Arnell\Documents\GitHub\whisp_sustaain\test\output\whisp_output_table.csv

# %% [markdown]
# Calculate risk category

# %%
# add risk columns to end of dataframe
df_w_risk = whisp.whisp_risk(df=df_formatted_stats)
# Out:
# C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\src\risk.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_column_name] = low_name
# C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\src\risk.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_column_name] = low_name
# C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\src\risk.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_column_name] = low_name
# C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\src\risk.py:225: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_column_name] = low_name
# C:\Users\Arnell\Documents\GitHub\whisp_sustaain\whisp\src\risk.py:166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[index, "EUDR_risk"] = "low"

# %% [markdown]
# Display table with risk columns

# %%
df_w_risk
# Out:
#     Plot_id  Geo_id  Plot_area_ha Geometry_type Country  \
# 0       NaN     NaN      1.939000       Polygon     GHA
# 1       NaN     NaN      4.152000       Polygon     GHA
# 2       NaN     NaN     16.600000       Polygon     GHA
# 3       NaN     NaN     31.212999       Polygon     IDN
# 4       NaN     NaN      1.964000       Polygon     IDN
# 5       NaN     NaN     12.725000       Polygon     IDN
# 6       NaN     NaN     20.882000       Polygon     IDN
# 7       NaN     NaN      8.279000       Polygon     CIV
# 8       NaN     NaN      1.981000       Polygon     CIV
# 9       NaN     NaN      3.797000       Polygon     CIV
# 10      NaN     NaN      3.615000       Polygon     CIV
# 11      NaN     NaN      0.236000       Polygon     NIC
# 12      NaN     NaN      2.255000       Polygon     NIC
# 13      NaN     NaN      0.799000       Polygon     NIC
# 14      NaN     NaN      0.269000       Polygon     NIC
# 15      NaN     NaN      1.019000       Polygon     CMR
# 16      NaN     NaN      1.006000       Polygon     CMR
# 17      NaN     NaN      4.242000       Polygon     CMR
# 18      NaN     NaN      0.435000       Polygon     CMR
# 19      NaN     NaN      8.086000       Polygon     VNM
# 20      NaN     NaN      7.574000       Polygon     VNM
# 21      NaN     NaN      7.363000       Polygon     VNM
# 22      NaN     NaN      6.879000       Polygon     VNM
# 23      NaN     NaN      6.204000       Polygon     VNM
# 24      NaN     NaN      6.192000       Polygon     VNM
# 25      NaN     NaN      5.648000       Polygon     VNM
# 26      NaN     NaN      5.578000       Polygon     VNM
# 27      NaN     NaN      5.296000       Polygon     FIN
# 28      NaN     NaN      3.725000       Polygon     SWE
# 29      NaN     NaN      3.014000       Polygon     FRA
# 30      NaN     NaN      2.649000       Polygon     FRA
#
#                   Admin_Level_1  Centroid_lon  Centroid_lat Unit water_flag  \
# 0                Ashanti Region     -1.611942      6.159540   ha          -
# 1                Ashanti Region     -1.644732      6.104735   ha          -
# 2                Western Region     -2.157144      5.981149   ha          -
# 3                 South Sumatra    103.956096     -3.054668   ha          -
# 4                 South Sumatra    103.970371     -3.068831   ha          -
# 5                 South Sumatra    103.975182     -3.082922   ha          -
# 6                 South Sumatra    103.977512     -3.083808   ha          -
# 7                       Lagunes     -4.101646      5.711935   ha          -
# 8                       Lagunes     -4.086848      5.673811   ha          -
# 9   District Autonome D'Abidjan     -4.119589      5.572136   ha          -
# 10                    Montagnes     -7.507022      6.071468   ha          -
# 11      Jinotega (Departamento)    -85.929673     13.298333   ha          -
# 12      Jinotega (Departamento)    -85.626848     13.539724   ha          -
# 13      Jinotega (Departamento)    -85.944465     13.166413   ha          -
# 14      Jinotega (Departamento)    -85.854650     13.290698   ha          -
# 15                       Centre     12.596546      4.232426   ha          -
# 16                       Centre     12.640107      4.199724   ha          -
# 17                       Centre     12.328070      4.258412   ha          -
# 18                       Centre     12.592323      4.229365   ha          -
# 19                      Gia Lai    108.063222     13.787460   ha          -
# 20                      ??k L?k    108.102666     12.939684   ha          -
# 21                      Gia Lai    108.048842     13.661566   ha          -
# 22                      Gia Lai    108.041977     13.736411   ha          -
# 23                     ??k Nông    107.588837     12.277016   ha          -
# 24                     ??k Nông    107.648926     12.324585   ha          -
# 25                      Gia Lai    108.120358     13.721797   ha          -
# 26                      ??k L?k    108.102197     12.913104   ha          -
# 27             Northern Savonia     27.032601     63.055631   ha          -
# 28               Gävleborgs län     15.882112     61.603567   ha          -
# 29           Nouvelle-Aquitaine     -0.556281     44.460203   ha          -
# 30           Nouvelle-Aquitaine     -0.521005     44.357837   ha          -
#
#     ...  TMF_deg_after_2020  TMF_def_after_2020  GFC_loss_after_2020  \
# 0   ...               0.000               0.000                0.000
# 1   ...               0.000               0.089                0.743
# 2   ...               0.089               0.000                0.000
# 3   ...               0.000               0.000                0.000
# 4   ...               0.000               0.000                0.000
# 5   ...               0.000               0.000                0.000
# 6   ...               0.714               0.000                0.000
# 7   ...               0.000               0.000                1.602
# 8   ...               0.000               0.000                0.000
# 9   ...               0.000               0.000                0.000
# 10  ...               0.000               0.000                0.000
# 11  ...               0.000               0.000                0.000
# 12  ...               0.000               0.000                0.367
# 13  ...               0.000               0.000                0.007
# 14  ...               0.000               0.000                0.126
# 15  ...               0.000               0.000                0.000
# 16  ...               0.000               0.000                0.000
# 17  ...               0.000               0.000                0.000
# 18  ...               0.000               0.000                0.000
# 19  ...               0.000               0.000                0.000
# 20  ...               0.000               0.000                0.000
# 21  ...               0.000               0.000                0.000
# 22  ...               0.000               0.000                0.000
# 23  ...               0.000               0.000                0.000
# 24  ...               0.000               0.000                0.000
# 25  ...               0.000               0.000                0.000
# 26  ...               0.000               0.000                0.000
# 27  ...               0.000               0.000                0.000
# 28  ...               0.000               0.000                0.542
# 29  ...               0.000               0.000                0.000
# 30  ...               0.000               0.000                0.000
#
#     MODIS_fire_after_2020  RADD_after_2020  Indicator_1_treecover  \
# 0                   0.000            0.000                    yes
# 1                   0.000            0.000                    yes
# 2                   0.000            1.063                    yes
# 3                   0.000            0.000                    yes
# 4                   0.000            0.000                    yes
# 5                   0.000            0.000                    yes
# 6                   0.000            0.000                    yes
# 7                   0.000            0.001                    yes
# 8                   0.000            0.000                    yes
# 9                   0.000            0.000                    yes
# 10                  0.000            0.000                    yes
# 11                  0.000            0.034                    yes
# 12                  0.000            0.000                    yes
# 13                  0.000            0.000                    yes
# 14                  0.000            0.000                    yes
# 15                  0.000            0.000                    yes
# 16                  0.000            0.006                    yes
# 17                  0.000            0.000                    yes
# 18                  0.000            0.000                    yes
# 19                  0.000            0.000                    yes
# 20                  0.000            0.000                    yes
# 21                  0.000            0.000                    yes
# 22                  0.000            0.000                    yes
# 23                  0.000            0.000                    yes
# 24                  0.000            0.000                    yes
# 25                  0.000            0.000                    yes
# 26                  0.000            0.000                    yes
# 27                  0.000            0.000                    yes
# 28                  0.000            0.000                    yes
# 29                  0.089            0.000                    yes
# 30                  0.000            0.000                    yes
#
#     Indicator_2_commodities  Indicator_3_disturbance_before_2020  \
# 0                       yes                                  yes
# 1                        no                                  yes
# 2                        no                                  yes
# 3                       yes                                  yes
# 4                       yes                                  yes
# 5                        no                                  yes
# 6                       yes                                  yes
# 7                       yes                                  yes
# 8                       yes                                  yes
# 9                       yes                                  yes
# 10                      yes                                  yes
# 11                       no                                  yes
# 12                       no                                   no
# 13                       no                                   no
# 14                       no                                   no
# 15                       no                                  yes
# 16                       no                                  yes
# 17                       no                                   no
# 18                       no                                  yes
# 19                       no                                   no
# 20                       no                                  yes
# 21                       no                                   no
# 22                      yes                                  yes
# 23                      yes                                  yes
# 24                       no                                  yes
# 25                      yes                                   no
# 26                       no                                  yes
# 27                       no                                  yes
# 28                       no                                  yes
# 29                       no                                  yes
# 30                       no                                  yes
#
#     Indicator_4_disturbance_after_2020         EUDR_risk
# 0                                   no               low
# 1                                  yes               low
# 2                                  yes               low
# 3                                   no               low
# 4                                   no               low
# 5                                   no               low
# 6                                  yes               low
# 7                                  yes               low
# 8                                   no               low
# 9                                   no               low
# 10                                  no               low
# 11                                 yes               low
# 12                                 yes              high
# 13                                 yes              high
# 14                                 yes              high
# 15                                  no               low
# 16                                 yes               low
# 17                                  no  more_info_needed
# 18                                  no               low
# 19                                  no  more_info_needed
# 20                                  no               low
# 21                                  no  more_info_needed
# 22                                  no               low
# 23                                  no               low
# 24                                  no               low
# 25                                  no               low
# 26                                  no               low
# 27                                  no               low
# 28                                 yes               low
# 29                                 yes               low
# 30                                  no               low
#
# [31 rows x 164 columns]

# %% [markdown]
# Export table with risk columns to csv

# %%
# Define output file path
output_risk_file = out_directory / "whisp_output_table_w_risk.csv" # edit as required

# Save statistics with added risk columns to CSV
df_w_risk.to_csv(path_or_buf=output_risk_file,index=False)

print(f"Table with risk columns saved to: {output_risk_file}")
# Out:
# Table with risk columns saved to: c:\Users\Arnell\Documents\GitHub\whisp_sustaain\test\output\whisp_output_table_w_risk.csv
